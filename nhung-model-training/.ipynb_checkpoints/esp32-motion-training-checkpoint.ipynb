# %%
import pandas as pd
import json
import warnings
warnings.filterwarnings('ignore')

# %%
def tranform_json_to_df(file_path, class_label):
    f = open(file_path)
    raw_json = json.load(f)
    f.close()
    esp32_data = raw_json['realtime']['esp32']
    df = pd.json_normalize(esp32_data)
    df.rename(columns={
        'accelerometer.x': 'AccX',
        'accelerometer.y': 'AccY',
        'accelerometer.z': 'AccZ',
        'gyro.x': 'GyroX',
        'gyro.y': 'GyroY',
        'gyro.z': 'GyroZ'
    }, inplace=True)
    df.drop(columns=['temperature'], inplace=True)
    df["Class"] = class_label
    return df

# %%
df_train_negative = tranform_json_to_df('data/esp32-training-negative.json', 0)
df_train_negative.head()
# Out:
#       AccX     AccY     AccZ    GyroX    GyroY    GyroZ  Class
# 0  0.98641  0.07901  8.33422 -0.03704 -0.00373  0.02851      0
# 1  0.99359  0.03112  8.33422 -0.03864 -0.00533  0.02825      0
# 2  1.00078  0.08140  8.32703 -0.03651 -0.00320  0.02984      0
# 3  1.03908  0.06943  8.33422 -0.03837 -0.00453  0.02745      0
# 4  0.99120  0.07901  8.31746 -0.03730 -0.00426  0.02798      0

# %%
df_train_positive = tranform_json_to_df('data/esp32-training-positive.json', 1)
df_train_positive.head()
# Out:
#       AccX     AccY     AccZ    GyroX    GyroY    GyroZ  Class
# 0 -3.31597  2.94966  4.92727  0.55371 -1.99607  0.10259      1
# 1 -3.28963  0.80206  6.75165  0.64750 -1.26463  0.58302      1
# 2  0.06943  1.04387  8.81545 -0.25234 -1.21560  0.07328      1
# 3  1.32639  1.25696  8.42520  0.64244 -0.82737  0.18040      1
# 4  3.76129  1.95846  6.19619 -0.47910 -1.26730 -0.68561      1

# %%
df_train = pd.concat([df_train_positive, df_train_negative], ignore_index=True)
df_train.groupby('Class')['Class'].count().plot.bar()

from sklearn.utils import shuffle
df_train = shuffle(df_train, random_state=42)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
plt.figure(figsize=(10, 5))
sns.boxplot(data=df_train_positive[['AccX', 'AccY', 'AccZ']])
plt.title('Boxplot for Acc +')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df_train_negative[['AccX', 'AccY', 'AccZ']])
plt.title('Boxplot for Acc -')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df_train_positive[['GyroX', 'GyroY', 'GyroZ']])
plt.title('Boxplot for Gyro +')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df_train_negative[['GyroX', 'GyroY', 'GyroZ']])
plt.title('Boxplot for Gyro +')
plt.show()

# %%
from pycaret.classification import *
exp_class= setup(df_train, target = 'Class',session_id=1)
# Out:
# <style type="text/css">
# #T_d2311_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d2311">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2311_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d2311_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2311_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2311_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d2311_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2311_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d2311_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d2311_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d2311_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d2311_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d2311_row3_col1" class="data row3 col1" >(3126, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d2311_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d2311_row4_col1" class="data row4 col1" >(3126, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d2311_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d2311_row5_col1" class="data row5 col1" >(2188, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d2311_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d2311_row6_col1" class="data row6 col1" >(938, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d2311_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_d2311_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d2311_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_d2311_row8_col1" class="data row8 col1" >1.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d2311_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_d2311_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d2311_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_d2311_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d2311_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_d2311_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d2311_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_d2311_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d2311_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_d2311_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d2311_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_d2311_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d2311_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_d2311_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d2311_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_d2311_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d2311_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_d2311_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d2311_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_d2311_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d2311_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d2311_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_d2311_row19_col1" class="data row19 col1" >180b</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models(errors="raise", exclude="lightgbm")
# Out:
# <style type="text/css">
# #T_f1275 th {
#   text-align: left;
# }
# #T_f1275_row0_col0, #T_f1275_row0_col3, #T_f1275_row0_col4, #T_f1275_row1_col0, #T_f1275_row1_col1, #T_f1275_row1_col3, #T_f1275_row1_col4, #T_f1275_row1_col5, #T_f1275_row1_col6, #T_f1275_row1_col7, #T_f1275_row2_col0, #T_f1275_row2_col1, #T_f1275_row2_col4, #T_f1275_row2_col5, #T_f1275_row2_col6, #T_f1275_row2_col7, #T_f1275_row3_col0, #T_f1275_row3_col1, #T_f1275_row3_col2, #T_f1275_row3_col4, #T_f1275_row3_col5, #T_f1275_row3_col6, #T_f1275_row3_col7, #T_f1275_row4_col0, #T_f1275_row4_col1, #T_f1275_row4_col2, #T_f1275_row4_col3, #T_f1275_row4_col5, #T_f1275_row4_col6, #T_f1275_row4_col7, #T_f1275_row5_col0, #T_f1275_row5_col1, #T_f1275_row5_col2, #T_f1275_row5_col4, #T_f1275_row5_col5, #T_f1275_row5_col6, #T_f1275_row5_col7, #T_f1275_row6_col0, #T_f1275_row6_col1, #T_f1275_row6_col2, #T_f1275_row6_col4, #T_f1275_row6_col5, #T_f1275_row6_col6, #T_f1275_row6_col7, #T_f1275_row7_col0, #T_f1275_row7_col1, #T_f1275_row7_col2, #T_f1275_row7_col3, #T_f1275_row7_col4, #T_f1275_row7_col5, #T_f1275_row7_col6, #T_f1275_row7_col7, #T_f1275_row8_col0, #T_f1275_row8_col1, #T_f1275_row8_col2, #T_f1275_row8_col3, #T_f1275_row8_col5, #T_f1275_row8_col6, #T_f1275_row8_col7, #T_f1275_row9_col0, #T_f1275_row9_col1, #T_f1275_row9_col2, #T_f1275_row9_col3, #T_f1275_row9_col5, #T_f1275_row9_col6, #T_f1275_row9_col7, #T_f1275_row10_col0, #T_f1275_row10_col1, #T_f1275_row10_col2, #T_f1275_row10_col3, #T_f1275_row10_col5, #T_f1275_row10_col6, #T_f1275_row10_col7, #T_f1275_row11_col0, #T_f1275_row11_col1, #T_f1275_row11_col2, #T_f1275_row11_col3, #T_f1275_row11_col4, #T_f1275_row11_col5, #T_f1275_row11_col6, #T_f1275_row11_col7, #T_f1275_row12_col0, #T_f1275_row12_col1, #T_f1275_row12_col2, #T_f1275_row12_col3, #T_f1275_row12_col4, #T_f1275_row12_col5, #T_f1275_row12_col6, #T_f1275_row12_col7 {
#   text-align: left;
# }
# #T_f1275_row0_col1, #T_f1275_row0_col2, #T_f1275_row0_col5, #T_f1275_row0_col6, #T_f1275_row0_col7, #T_f1275_row1_col2, #T_f1275_row2_col2, #T_f1275_row2_col3, #T_f1275_row3_col3, #T_f1275_row4_col4, #T_f1275_row5_col3, #T_f1275_row6_col3, #T_f1275_row8_col4, #T_f1275_row9_col4, #T_f1275_row10_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f1275_row0_col8, #T_f1275_row1_col8, #T_f1275_row2_col8, #T_f1275_row3_col8, #T_f1275_row4_col8, #T_f1275_row5_col8, #T_f1275_row6_col8, #T_f1275_row7_col8, #T_f1275_row8_col8, #T_f1275_row9_col8, #T_f1275_row10_col8, #T_f1275_row11_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f1275_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f1275">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1275_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f1275_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f1275_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f1275_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f1275_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f1275_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f1275_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f1275_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_f1275_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1275_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_f1275_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_f1275_row0_col1" class="data row0 col1" >0.9954</td>
#       <td id="T_f1275_row0_col2" class="data row0 col2" >0.9999</td>
#       <td id="T_f1275_row0_col3" class="data row0 col3" >0.9877</td>
#       <td id="T_f1275_row0_col4" class="data row0 col4" >0.9986</td>
#       <td id="T_f1275_row0_col5" class="data row0 col5" >0.9931</td>
#       <td id="T_f1275_row0_col6" class="data row0 col6" >0.9897</td>
#       <td id="T_f1275_row0_col7" class="data row0 col7" >0.9897</td>
#       <td id="T_f1275_row0_col8" class="data row0 col8" >0.0680</td>
#     </tr>
#     <tr>
#       <th id="T_f1275_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_f1275_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_f1275_row1_col1" class="data row1 col1" >0.9950</td>
#       <td id="T_f1275_row1_col2" class="data row1 col2" >0.9999</td>
#       <td id="T_f1275_row1_col3" class="data row1 col3" >0.9877</td>
#       <td id="T_f1275_row1_col4" class="data row1 col4" >0.9972</td>
#       <td id="T_f1275_row1_col5" class="data row1 col5" >0.9924</td>
#       <td id="T_f1275_row1_col6" class="data row1 col6" >0.9886</td>
#       <td id="T_f1275_row1_col7" class="data row1 col7" >0.9887</td>
#       <td id="T_f1275_row1_col8" class="data row1 col8" >0.1300</td>
#     </tr>
#     <tr>
#       <th id="T_f1275_level0_row2" class="row_heading level0 row2" >ada</th>
#       <td id="T_f1275_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#       <td id="T_f1275_row2_col1" class="data row2 col1" >0.9945</td>
#       <td id="T_f1275_row2_col2" class="data row2 col2" >0.9999</td>
#       <td id="T_f1275_row2_col3" class="data row2 col3" >0.9890</td>
#       <td id="T_f1275_row2_col4" class="data row2 col4" >0.9945</td>
#       <td id="T_f1275_row2_col5" class="data row2 col5" >0.9917</td>
#       <td id="T_f1275_row2_col6" class="data row2 col6" >0.9876</td>
#       <td id="T_f1275_row2_col7" class="data row2 col7" >0.9877</td>
#       <td id="T_f1275_row2_col8" class="data row2 col8" >0.0530</td>
#     </tr>
#     <tr>
#       <th id="T_f1275_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_f1275_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_f1275_row3_col1" class="data row3 col1" >0.9936</td>
#       <td id="T_f1275_row3_col2" class="data row3 col2" >0.9998</td>
#       <td id="T_f1275_row3_col3" class="data row3 col3" >0.9890</td>
#       <td id="T_f1275_row3_col4" class="data row3 col4" >0.9918</td>
#       <td id="T_f1275_row3_col5" class="data row3 col5" >0.9904</td>
#       <td id="T_f1275_row3_col6" class="data row3 col6" >0.9856</td>
#       <td id="T_f1275_row3_col7" class="data row3 col7" >0.9856</td>
#       <td id="T_f1275_row3_col8" class="data row3 col8" >0.1000</td>
#     </tr>
#     <tr>
#       <th id="T_f1275_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_f1275_row4_col0" class="data row4 col0" >K Neighbors Classifier</td>
#       <td id="T_f1275_row4_col1" class="data row4 col1" >0.9881</td>
#       <td id="T_f1275_row4_col2" class="data row4 col2" >0.9909</td>
#       <td id="T_f1275_row4_col3" class="data row4 col3" >0.9644</td>
#       <td id="T_f1275_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_f1275_row4_col5" class="data row4 col5" >0.9818</td>
#       <td id="T_f1275_row4_col6" class="data row4 col6" >0.9730</td>
#       <td id="T_f1275_row4_col7" class="data row4 col7" >0.9734</td>
#       <td id="T_f1275_row4_col8" class="data row4 col8" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_f1275_level0_row5" class="row_heading level0 row5" >nb</th>
#       <td id="T_f1275_row5_col0" class="data row5 col0" >Naive Bayes</td>
#       <td id="T_f1275_row5_col1" class="data row5 col1" >0.9877</td>
#       <td id="T_f1275_row5_col2" class="data row5 col2" >0.9969</td>
#       <td id="T_f1275_row5_col3" class="data row5 col3" >0.9890</td>
#       <td id="T_f1275_row5_col4" class="data row5 col4" >0.9744</td>
#       <td id="T_f1275_row5_col5" class="data row5 col5" >0.9816</td>
#       <td id="T_f1275_row5_col6" class="data row5 col6" >0.9723</td>
#       <td id="T_f1275_row5_col7" class="data row5 col7" >0.9724</td>
#       <td id="T_f1275_row5_col8" class="data row5 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_f1275_level0_row6" class="row_heading level0 row6" >qda</th>
#       <td id="T_f1275_row6_col0" class="data row6 co

# %%
model = create_model(best_model)
final_model = finalize_model(model)
# Out:
# <style type="text/css">
# #T_5b6e8_row10_col0, #T_5b6e8_row10_col1, #T_5b6e8_row10_col2, #T_5b6e8_row10_col3, #T_5b6e8_row10_col4, #T_5b6e8_row10_col5, #T_5b6e8_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5b6e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b6e8_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5b6e8_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5b6e8_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5b6e8_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5b6e8_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5b6e8_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5b6e8_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b6e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b6e8_row0_col0" class="data row0 col0" >0.9909</td>
#       <td id="T_5b6e8_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_5b6e8_row0_col2" class="data row0 col2" >0.9726</td>
#       <td id="T_5b6e8_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_5b6e8_row0_col4" class="data row0 col4" >0.9861</td>
#       <td id="T_5b6e8_row0_col5" class="data row0 col5" >0.9793</td>
#       <td id="T_5b6e8_row0_col6" class="data row0 col6" >0.9795</td>
#     </tr>
#     <tr>
#       <th id="T_5b6e8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5b6e8_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_5b6e8_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_5b6e8_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_5b6e8_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_5b6e8_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_5b6e8_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_5b6e8_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5b6e8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5b6e8_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_5b6e8_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_5b6e8_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_5b6e8_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_5b6e8_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_5b6e8_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_5b6e8_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5b6e8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5b6e8_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_5b6e8_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_5b6e8_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_5b6e8_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_5b6e8_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_5b6e8_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_5b6e8_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5b6e8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5b6e8_row4_col0" class="data row4 col0" >0.9954</td>
#       <td id="T_5b6e8_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_5b6e8_row4_col2" class="data row4 col2" >0.9863</td>
#       <td id="T_5b6e8_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_5b6e8_row4_col4" class="data row4 col4" >0.9931</td>
#       <td id="T_5b6e8_row4_col5" class="data row4 col5" >0.9897</td>
#       <td id="T_5b6e8_row4_col6" class="data row4 col6" >0.9897</td>
#     </tr>
#     <tr>
#       <th id="T_5b6e8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5b6e8_row5_col0" class="data row5 col0" >0.9863</td>
#       <td id="T_5b6e8_row5_col1" class="data row5 col1" >0.9997</td>
#       <td id="T_5b6e8_row5_col2" class="data row5 col2" >0.9726</td>
#       <td id="T_5b6e8_row5_col3" class="data row5 col3" >0.9861</td>
#       <td id="T_5b6e8_row5_col4" class="data row5 col4" >0.9793</td>
#       <td id="T_5b6e8_row5_col5" class="data row5 col5" >0.9691</td>
#       <td id="T_5b6e8_row5_col6" class="data row5 col6" >0.9691</td>
#     </tr>
#     <tr>
#       <th id="T_5b6e8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5b6e8_row6_col0" class="data row6 col0" >0.9954</td>
#       <td id="T_5b6e8_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_5b6e8_row6_col2" class="data row6 col2" >0.9863</td>
#       <td id="T_5b6e8_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_5b6e8_row6_col4" class="data row6 col4" >0.9931</td>
#       <td id="T_5b6e8_row6_col5" class="data row6 col5" >0.9897</td>
#       <td id="T_5b6e8_row6_col6" class="data row6 col6" >0.9897</td>
#     </tr>
#     <tr>
#       <th id="T_5b6e8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5b6e8_row7_col0" class="data row7 col0" >0.9954</td>
#       <td id="T_5b6e8_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_5b6e8_row7_col2" class="data row7 col2" >0.9863</td>
#       <td id="T_5b6e8_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_5b6e8_row7_col4" class="data row7 col4" >0.9931</td>
#       <td id="T_5b6e8_row7_col5" class="data row7 col5" >0.9897</td>
#       <td id="T_5b6e8_row7_col6" class="data row7 col6" >0.9897</td>
#     </tr>
#     <tr>
#       <th id="T_5b6e8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5b6e8_row8_col0" class="data row8 col0" >0.9908</td>
#       <td id="T_5b6e8_row8_col1" class="data row8 col1" >0.9998</td>
#       <td id="T_5b6e8_row8_col2" class="data row8 col2" >0.9726</td>
#       <td id="T_5b6e8_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_5b6e8_row8_col4" class="data row8 col4" >0.9861</td>
#       <td id="T_5b6e8_row8_col5" class="data row8 col5" >0.9793</td>
#       <td id="T_5b6e8_row8_col6" class="data row8 col6" >0.9795</td>
#     </tr>
#     <tr>
#       <th id="T_5b6e8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5b6e8_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_5b6e8_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_5b6e8_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_5b6e8_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_5b6e8_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_5b6e8_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_5b6e8_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5b6e8_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_5b6e8_row10_col0" class="data row10 col0" >0.9954</td>
#       <td id="T_5b6e8_row10_col1" class="data row10 col1" >0.9999</td>
#       <td id="T_5b6e8_row10_col2" class="data row10 col2" >0.9877</td>
#       <td id="T_5b6e8_row10_col3" class="data row10 col3" >0.9986</td>
#       <td id="T_5b6e8_row10_col4" class="data row10 col4" >0.9931</td>
#       <td id="T_5b6e8_row10_col5" class="data row10 col5" >0.9897</td>
#       <td id="T_5b6e8_row10_col6" class="data row10 col6" >0.9897</td>
#     </tr>
#     <tr>
#       <th id="T_5b6e8_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_5b6e8_row11_col0" class="data row11 col0" >0.0046</td>
#       <td id="T_5b6e8_row11_col1" class="data row11 col1" >0.0001</td>
#       <td id="T_5b6e8_row11_col2" class="data row11 col2" >0.0114</td>
#       <td id="T_5b6e8_row11_col3" class="data row11 col3" >0.0042</td>
#       <td id="T_5b6e8_row11_col4

# %%
# load test data
df_test_negative = tranform_json_to_df('data/esp32-test-negative.json', 0)
df_test_positive = tranform_json_to_df('data/esp32-test-positive.json', 1)
df_test = pd.concat([df_test_negative, df_test_positive], ignore_index=True)
df_test = shuffle(df_train, random_state=42)

# %%
unseen_predictions = predict_model(final_model, data=df_test)
unseen_predictions.tail(15)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b421e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b421e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b421e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_b421e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_b421e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_b421e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_b421e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_b421e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_b421e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b421e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b421e_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_b421e_row0_col1" class="data row0 col1" >0.9971</td>
#       <td id="T_b421e_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_b421e_row0_col3" class="data row0 col3" >0.9914</td>
#       <td id="T_b421e_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_b421e_row0_col5" class="data row0 col5" >0.9957</td>
#       <td id="T_b421e_row0_col6" class="data row0 col6" >0.9935</td>
#       <td id="T_b421e_row0_col7" class="data row0 col7" >0.9935</td>
#     </tr>
#   </tbody>
# </table>
#           AccX      AccY       AccZ    GyroX    GyroY    GyroZ  Class  \
# 3023   1.04627   0.04070   8.341400 -0.03704 -0.00426  0.02851      0
# 240    5.78439   3.39737   7.546520 -0.98858 -0.29791  1.74959      1
# 1636   0.69671   0.43335   8.279150 -0.04104 -0.05782  0.04850      0
# 345   -5.85861   0.28970   5.858610 -1.89322 -2.85488  1.38747      1
# 3035   1.05345   0.04310   8.358160 -0.03730 -0.00373  0.02931      0
# 2263   1.54665   0.66080   8.425200 -0.06075 -0.02585  0.03757      0
# 269    0.74699 -11.22402   4.826710  1.84738  1.11541 -2.27346      1
# 2965   1.03908   0.02394   8.339000 -0.03677 -0.00426  0.02904      0
# 1471   1.01993   0.12689   8.350980 -0.03597 -0.00426  0.02851      0
# 2446   0.23463  -0.25618   8.401250 -0.00453  0.12657  0.12950      0
# 2747   0.64883  -0.83558   8.350980 -0.04450 -0.02611  0.02931      0
# 2117   1.76453   0.91937   8.240840 -0.05915  0.03597  0.01599      0
# 941   -9.29669  -3.68946   6.454770  4.67455 -4.25967 -3.74060      1
# 731    4.82432  -6.55054  17.683571 -2.93269  2.06349 -4.34680      1
# 781  -18.62928  -0.06704  -2.772490  3.00037 -1.58066  3.16717      1
#
#       prediction_label  prediction_score
# 3023                 0               1.0
# 240                  1               1.0
# 1636                 0               1.0
# 345                  1               1.0
# 3035                 0               1.0
# 2263                 0               1.0
# 269                  1               1.0
# 2965                 0               1.0
# 1471                 0               1.0
# 2446                 0               1.0
# 2747                 0               1.0
# 2117                 0               1.0
# 941                  1               1.0
# 731                  1               1.0
# 781                  1               1.0

# %%
save_model(final_model, "driving-behavior-1")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['AccX', 'AccY', 'AccZ', 'GyroX',
#                                               'GyroY', 'GyroZ'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categorical_imputer',
#                   TransformerWrapper(exclude=None, includ...
#                   ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                                        class_weight=None, criterion='gini',
#                                        max_depth=None, max_features='sqrt',
#                                        max_leaf_nodes=None, max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        monotonic_cst=None, n_estimators=100,
#                                        n_jobs=-1, oob_score=False,
#                                        random_state=1, verbose=0,
#                                        warm_start=False))],
#           verbose=False),
#  'driving-behavior-1.pkl')
